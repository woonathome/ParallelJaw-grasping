# %% [markdown]
# # MuJoCo Parallel Jaw Grasp Test
#
# HTML grasp 결과를 읽어 top pair grasp + 3축 perturbation을 수행합니다.
# 필요하면 MuJoCo native viewer 창을 함께 띄울 수 있습니다.

# %%
import os, glob
HTML_PATHs = glob.glob("./Grasping_Results_SurfaceContact/*/1-*.html")

# %%
HTML_PATH = HTML_PATHs[-1]
HTML_PATH
# Out:
# './Grasping_Results_SurfaceContact\\custom_ind\\1-grasping_pairs_feasible_steel_connector_60sol.html'

# %%
from Grasping_Mujoco_Sim import run_from_html

# result = run_from_html(
#     html_path=HTML_PATH,
#     depth_speed=1.0,
#     width_speed=1.0,
#     height_speed=1.0,
#     friction=0.8,
#     grasp_force=100.0,
#     gravity_z=0.0,             # 바닥 없으면 0 권장
#     tighten_step=0.001,
#     max_tighten_iters=100,
#     open_viewer=True,
#     realtime_viewer=True,
# )
# result
# Out:
# {'pair_name': 'pair 0 - faces (592, 1269) - yaw 90',
#  'legend_group': 'pair 0 - faces (592, 1269) - yaw 90',
#  'source_html': 'Grasping_Results_SurfaceContact\\custom_ind\\1-grasping_pairs_feasible_steel_connector_60sol.html',
#  'config': {'friction': 0.9,
#   'grasp_force': 140.0,
#   'object_density': 850.0,
#   'gravity_z': 0.0,
#   'contact_condim': 6,
#   'contact_cone': 'elliptic',
#   'contact_impratio': 10.0,
#   'solver_iterations': 120,
#   'noslip_iterations': 16,
#   'contact_solref_timeconst': 0.001,
#   'contact_solref_dampratio': 1.0,
#   'contact_solimp0': 0.995,
#   'contact_solimp1': 0.999,
#   'contact_solimp2': 0.0005,
#   'finger_kp': 26000.0,
#   'pad_width': 0.034,
#   'pad_height': 0.021,
#   'pad_depth': 0.007,
#   'pre_clearance': 0.004,
#   'squeeze_extra': 0.0015,
#   'close_ramp': True,
#   'require_dual_contact': True,
#   'tighten_step': 0.001,
#   'max_tighten_iters': 1000,
#   'tighten_settle_time': 0.03,
#   'recenter_step': 0.0008,
# ...
